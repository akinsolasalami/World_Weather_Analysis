# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitiudes to a list. 
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a list for holding rhe cities..
cities = []
# Identify the nearest vity for each latitiude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will ad it to the cities list. 
    if city not in cities:
        cities.append(city)
# print the city count to confirm suffiecient count. 
len(cities)
# Out:
# 779

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})
    except:
        print("City not found. Skipping...")
        pass

    # Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | castro
# Processing Record 2 of Set 1 | sidney
# Processing Record 3 of Set 1 | khatanga
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | narsaq
# Processing Record 7 of Set 1 | monywa
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | taoudenni
# Processing Record 12 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 1 | japura
# Processing Record 14 of Set 1 | carballo
# Processing Record 15 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | pesca
# Processing Record 18 of Set 1 | helong
# Processing Record 19 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 1 | pula
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | richards bay
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | najran
# Processing Record 25 of Set 1 | iqaluit
# Processing Record 26 of Set 1 | suihua
# Processing Record 27 of Set 1 | jiaojiang
# Processing Record 28 of Set 1 | jiuquan
# Processing Record 29 of Set 1 | luganville
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | aklavik
# Processing Record 34 of Set 1 | hokitika
# Processing Record 35 of Set 1 | hovd
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | grande-synthe
# Processing Record 38 of Set 1 | la ronge
# Processing Record 39 of Set 1 | barrow
# Processing Record 40 of Set 1 | kapaa
# Processing Record 41 of Set 1 | taltal
# Processing Record 42 of Set 1 | pevek
# Processing Record 43 of Set 1 | college
# Processing Record 44 of Set 1 | kieta
# Processing Record 45 of Set 1 | bethel
# Processing Record 46 of Set 1 | east london
# Processing Record 47 of Set 1 | longyearbyen
# Processing Record 48 of Set 1 | norman wells
# Processing Record 49 of Set 1 | mahebourg
# Processing Record 50 of Set 1 | tiksi
# Processing Record 1 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 2 | dunedin
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | barra patuca
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | airai
# Processing Record 8 of Set 2 | hede
# Processing Record 9 of Set 2 | kamenka
# Processing Record 10 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 2 | teul
# City not found. Skipping...
# Processing Record 12 of Set 2 | tuktoyaktuk
# Processing Record 13 of Set 2 | pangnirtung
# Processing Record 14 of Set 2 | torrevieja
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | qaanaaq
# Processing Record 17 of Set 2 | san matias
# Processing Record 18 of Set 2 | mahibadhoo
# Processing Record 19 of Set 2 | bull savanna
# Processing Record 20 of Set 2 | chokurdakh
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | constitucion
# Processing Record 23 of Set 2 | padang
# Processing Record 24 of Set 2 | bushehr
# Processing Record 25 of Set 2 | hashtrud
# Processing Record 26 of Set 2 | kibala
# Processing Record 27 of Set 2 | mar del plata
# Processing Record 28 of Set 2 | tasiilaq
# Processing Record 29 of Set 2 | maloshuyka
# City not found. Skipping...
# Processing Record 30 of Set 2 | axim
# Processing Record 31 of Set 2 | virtsu
# Processing Record 32 of Set 2 | kaseda
# Processing Record 33 of Set 2 | manaus
# Processing Record 34 of Set 2 | lokosovo
# Processing Record 35 of Set 2 | kantunilkin
# Processing Record 36 of Set 2 | solovetskiy
# City not found. Skipping...
# Processing Record 37 of Set 2 | saldanha
# Processing Record 38 of Set 2 | merke
# Processing Record 39 of Set 2 | barkhan
# Processing Record 40 of Set 2 | port alfred
# Processing Record 41 of Set 2 | krasnoselkup
# Processing Record 42 of Set 2 | vaini
# Processing Record 43 of Set 2 | punta arenas
# Processing Record 44 of Set 2 | nanortalik
# Processing Record 45 of Set 2 | victoria
# Processing Record 46 of Set 2 | masingbi
# Processing Record 47 of Set 2 | cherskiy
# Processing Record 48 of Set 2 | villamontes
# Processing Record 49 of Set 2 | lodja
# Processing Record 50 of Set 2 | kodiak
# Processing Record 1 of Set 3 | thompson
# Processing Record 2 of Set 3 | qarchak
# Processing Record 3 of Set 3 | letlhakeng
# Processing Record 4 of Set 3 | lavrentiya
# Processing Record 5 of Set 3 | mount isa
# Processing Record 6 of Set 3 | manzanillo
# Processing Record 7 of Set 3 | ulaanbaatar
# Processing Record 8 of Set 3 | fort-shevchenko
# Processing Record 9 of Set 3 | young
# Processing Record 10 of Set 3 | upernavik
# Processing Record 11 of Set 3 | saint anthony
# Processing Record 12 of Set 3 | lebu
# Processing Record 13 of Set 3 | broome
# Processing Record 14 of Set 3 | banda aceh
# Processing Record 15 of Set 3 | ahipara
# Processing Record 16 of Set 3 | suez
# Processing Record 17 of Set 3 | louis trichardt
# Processing Record 18 of Set 3 | chuy
# Processing Record 19 of Set 3 | maceio
# Processing Record 20 of Set 3 | klyuchi
# Processing Record 21 of Set 3 | lagoa
# Processing Record 22 of Set 3 | port elizabeth
# Processing Record 23 of Set 3 | mogadishu
# Processing Record 24 of Set 3 | aswan
# Processing Record 25 of Set 3 | antalaha
# Processing Record 26 of Set 3 | kandrian
# Processing Record 27 of Set 3 | carnarvon
# Processing Record 28 of Set 3 | thunder bay
# Processing Record 29 of Set 3 | hamilton
# Processing Record 30 of Set 3 | kayes
# Processing Record 31 of Set 3 | port blair
# Processing Record 32 of Set 3 | geraldton
# Processing Record 33 of Set 3 | ciudad bolivar
# Processing Record 34 of Set 3 | atambua
# Processing Record 35 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 3 | belaya gora
# Processing Record 37 of Set 3 | severo-kurilsk
# Processing Record 38 of Set 3 | arlit
# Processing Record 39 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 3 | karasburg
# Processing Record 41 of Set 3 | atocha
# Processing Record 42 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 3 | dinghai
# Processing Record 44 of Set 3 | macenta
# Processing Record 45 of Set 3 | khash
# Processing Record 46 of Set 3 | mecca
# Processing Record 47 of Set 3 | makarov
# Processing Record 48 of Set 3 | egvekinot
# Processing Record 49 of Set 3 | masyaf
# Processing Record 50 of Set 3 | saint-augustin
# Processing Record 1 of Set 4 | caravelas
# Processing Record 2 of Set 4 | muromtsevo
# Processing Record 3 of Set 4 | faanui
# Processing Record 4 of Set 4 | lichinga
# Processing Record 5 of Set 4 | saint-joseph
# Processing Record 6 of Set 4 | baykit
# Processing Record 7 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 4 | mbandaka
# Processing Record 9 of Set 4 | hobart
# Processing Record 10 of Set 4 | clyde
# Processing Record 11 of Set 4 | buin
# Processing Record 12 of Set 4 | atchison
# Processing Record 13 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 4 | shimoda
# Processing Record 15 of Set 4 | dianopolis
# City not found. Skipping...
# Processing Record 16 of Set 4 | guerrero negro
# Processing Record 17 of Set 4 | saskylakh
# Processing Record 18 of Set 4 | iwanai
# Processing Record 19 of Set 4 | san cristobal
# Processing Record 20 of Set 4 | ciudad del maiz
# Processing Record 21 of Set 4 | rameshki
# Processing Record 22 of Set 4 | cerrito
# Processing Record 23 of Set 4 | bethanien
# Processing Record 24 of Set 4 | port hedland
# Processing Record 25 of Set 4 | nioro
# Processing Record 26 of Set 4 | barcelos
# Processing Record 27 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 4 | ballina
# Processing Record 29 of Set 4 | komsomolskiy
# Processing Record 30 of Set 4 | grenfell
# Processing Record 31 of Set 4 | salinopolis
# Processing Record 32 of Set 4 | florianopolis
# Processing Record 33 of Set 4 | bubaque
# Processing Record 34 of Set 4 | busayra
# Processing Record 35 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 36 of Set 4 | ribeira grande
# Processing Record 37 of Set 4 | rio grande
# Processing Record 38 of Set 4 | big rapids
# Processing Record 39 of Set 4 | yangambi
# Processing Record 40 of Set 4 | okhotsk
# Processing Record 41 of Set 4 | georgetown
# Processing Record 42 of Set 4 | mugi
# Processing Record 43 of Set 4 | ponta do sol
# Processing Record 44 of Set 4 | monduli
# Processing Record 45 of Set 4 | cayenne
# Processing Record 46 of Set 4 | kaitangata
# Processing Record 47 of Set 4 | guajara-mirim
# City not found. Skipping...
# Processing Record 48 of Set 4 | kutum
# Processing Record 49 of Set 4 | borskoye
# Processing Record 50 of Set 4 | sakaraha
# Processing Record 1 of Set 5 | qeshm
# Processing Record 2 of Set 5 | butaritari
# Processing Record 3 of Set 5 | vestmanna
# Processing Record 4 of Set 5 | qaqortoq
# Processing Record 5 of Set 5 | provideniya
# Processing Record 6 of Set 5 | praya
# Processing Record 7 of Set 5 | mount gambier
# Processing Record 8 of Set 5 | bayburt
# Processing Record 9 of Set 5 | souillac
# Processing Record 10 of Set 5 | yenagoa
# Processing Record 11 of Set 5 | ozgon
# City not found. Skipping...
# Processing Record 12 of Set 5 | lorengau
# Processing Record 13 of Set 5 | dalvik
# Processing Record 14 of Set 5 | vila velha
# Processing Record 15 of Set 5 | luderitz
# Processing Record 16 of Set 5 | san quintin
# Processing Record 17 of Set 5 | lata
# Processing Record 18 of Set 5 | merauke
# Processing Record 19 of Set 5 | fortuna foothills
# Processing Record 20 of Set 5 | sembe
# Processing Record 21 of Set 5 | gatton
# Processing Record 22 of Set 5 | vila franca do campo
# Processing Record 23 of Set 5 | russell
# Processing Record 24 of Set 5 | desert hot springs
# Processing Record 25 of Set 5 | sonoita
# Processing Record 26 of Set 5 | sumbe
# Processing Record 27 of Set 5 | coquimbo
# Processing Record 28 of Set 5 | arraial do cabo
# Processing Record 29 of Set 5 | mezen
# Processing Record 30 of Set 5 | janakpur road
# City not found. Skipping...
# Processing Record 31 of Set 5 | oistins
# Processing Record 32 of Set 5 | seoul
# Processing Record 33 of Set 5 | itarantim
# Processing Record 34 of Set 5 | sinnamary
# Processing Record 35 of Set 5 | ust-ishim
# Processing Record 36 of Set 5 | tilsonburg
# City not found. Skipping...
# Processing Record 37 of Set 5 | katsuura
# Processing Record 38 of Set 5 | lewistown
# Processing Record 39 of Set 5 | biltine
# Processing Record 40 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 5 | san severo
# Processing Record 42 of Set 5 | namatanai
# Processing Record 43 of Set 5 | esperance
# Processing Record 44 of Set 5 | cordoba
# Processing Record 45 of Set 5 | igrim
# Processing Record 46 of Set 5 | sola
# Processing Record 47 of Set 5 | korla
# Processing Record 48 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 5 | laiwu
# Processing Record 50 of Set 5 | flin flon
# Processing Record 1 of Set 6 | labuhan
# Processing Record 2 of Set 6 | quelimane
# Processing Record 3 of Set 6 | kurilsk
# Processing Record 4 of Set 6 | general roca
# Processing Record 5 of Set 6 | yellowknife
# Processing Record 6 of Set 6 | beruwala
# Processing Record 7 of Set 6 | malkangiri
# Processing Record 8 of Set 6 | fortuna
# Processing Record 9 of Set 6 | bandarbeyla
# Processing Record 10 of Set 6 | mizoch
# Processing Record 11 of Set 6 | necochea
# Processing Record 12 of Set 6 | bonavista
# Processing Record 13 of Set 6 | maracacume
# Processing Record 14 of Set 6 | sakaiminato
# Processing Record 15 of Set 6 | cabo san lucas
# Processing Record 16 of Set 6 | isangel
# Processing Record 17 of Set 6 | fairbanks
# Processing Record 18 of Set 6 | bairiki
# Processing Record 19 of Set 6 | rocha
# Processing Record 20 of Set 6 | the valley
# Processing Record 21 of Set 6 | ulladulla
# Processing Record 22 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 6 | sabang
# Processing Record 24 of Set 6 | nambucca heads
# Processing Record 25 of Set 6 | mayya
# Processing Record 26 of Set 6 | fredericksburg
# Processing Record 27 of Set 6 | bengkulu
# Processing Record 28 of Set 6 | roald
# Processing Record 29 of Set 6 | durban
# Processing Record 30 of Set 6 | san ramon
# Processing Record 31 of Set 6 | grande-riviere
# City not found. Skipping...
# Processing Record 32 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 6 | sao filipe
# Processing Record 34 of Set 6 | natal
# Processing Record 35 of Set 6 | sertania
# Processing Record 36 of Set 6 | ushumun
# Processing Record 37 of Set 6 | neiafu
# Processing Record 38 of Set 6 | dragoesti
# Processing Record 39 of Set 6 | oshawa
# Processing Record 40 of Set 6 | vao
# Processing Record 41 of Set 6 | salair
# Processing Record 42 of Set 6 | caibarien
# Processing Record 43 of Set 6 | talnakh
# Processing Record 44 of Set 6 | hami
# Processing Record 45 of Set 6 | alofi
# Processing Record 46 of Set 6 | shenjiamen
# Processing Record 47 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 48 of Set 6 | sabya
# Processing Record 49 of Set 6 | husavik
# Processing Record 50 of Set 6 | rincon
# Processing Record 1 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 7 | khanpur
# Processing Record 3 of Set 7 | dingle
# Processing Record 4 of Set 7 | sorong
# Processing Record 5 of Set 7 | mazagao
# Processing Record 6 of Set 7 | kalemie
# Processing Record 7 of Set 7 | nieuw nickerie
# Processing Record 8 of Set 7 | athabasca
# Processing Record 9 of Set 7 | los llanos de aridane
# Processing Record 10 of Set 7 | sandpoint
# Processing Record 11 of Set 7 | sambava
# Processing Record 12 of Set 7 | gazli
# Processing Record 13 of Set 7 | tabou
# Processing Record 14 of Set 7 | erzin
# Processing Record 15 of Set 7 | santiago tuxtla
# Processing Record 16 of Set 7 | hare bay
# Processing Record 17 of Set 7 | nhulunbuy
# Processing Record 18 of Set 7 | aykhal
# Processing Record 19 of Set 7 | obo
# Processing Record 20 of Set 7 | san patricio
# Processing Record 21 of Set 7 | ponta delgada
# Processing Record 22 of Set 7 | tenenkou
# Processing Record 23 of Set 7 | xichang
# Processing Record 24 of Set 7 | torbay
# Processing Record 25 of Set 7 | tsaratanana
# Processing Record 26 of Set 7 | rundu
# Processing Record 27 of Set 7 | beloha
# Processing Record 28 of Set 7 | goya
# Processing Record 29 of Set 7 | mahina
# Processing Record 30 of Set 7 | vinh
# Processing Record 31 of Set 7 | kota kinabalu
# Processing Record 32 of Set 7 | yamada
# Processing Record 33 of Set 7 | eyl
# Processing Record 34 of Set 7 | baiyin
# Processing Record 35 of Set 7 | nabire
# Processing Record 36 of Set 7 | kavaratti
# Processing Record 37 of Set 7 | plettenberg bay
# Processing Record 38 of Set 7 | kiama
# Processing Record 39 of Set 7 | coihaique
# Processing Record 40 of Set 7 | pinjaur
# Processing Record 41 of Set 7 | sao felix do xingu
# Processing Record 42 of Set 7 | sao joao da barra
# Processing Record 43 of Set 7 | antofagasta
# Processing Record 44 of Set 7 | aginskoye
# Processing Record 45 of Set 7 | saint-georges
# Processing Record 46 of Set 7 | tres picos
# Processing Record 47 of Set 7 | encruzilhada do sul
# Processing Record 48 of Set 7 | salalah
# Processing Record 49 of Set 7 | pombas
# Processing Record 50 of Set 7 | zalari
# Processing Record 1 of Set 8 | grand-santi
# Processing Record 2 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 8 | srednekolymsk
# Processing Record 4 of Set 8 | salinas
# Processing Record 5 of Set 8 | lima
# Processing Record 6 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 8 | bathsheba
# Processing Record 8 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 9 of Set 8 | beliator
# Processing Record 10 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 8 | hithadhoo
# Processing Record 12 of Set 8 | sao jose da coroa grande
# Processing Record 13 of Set 8 | grand haven
# Processing Record 14 of Set 8 | codrington
# Processing Record 15 of Set 8 | honiara
# Processing Record 16 of Set 8 | thung song
# Processing Record 17 of Set 8 | leh
# Processing Record 18 of Set 8 | kargil
# Processing Record 19 of Set 8 | thinadhoo
# Processing Record 20 of Set 8 | stykkisholmur
# Processing Record 21 of Set 8 | gamboma
# Processing Record 22 of Set 8 | sand springs
# Processing Record 23 of Set 8 | otane
# Processing Record 24 of Set 8 | kornye
# Processing Record 25 of Set 8 | colac
# Processing Record 26 of Set 8 | kuusamo
# Processing Record 27 of Set 8 | saint-marc-des-carrieres
# Processing Record 28 of Set 8 | vestmannaeyjar
# Processing Record 29 of Set 8 | kaeo
# Processing Record 30 of Set 8 | jega
# Processing Record 31 of Set 8 | tezu
# Processing Record 32 of Set 8 | kirakira
# Processing Record 33 of Set 8 | avera
# Processing Record 34 of Set 8 | kolokani
# Processing Record 35 of Set 8 | teknaf
# Processing Record 36 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 8 | markala
# Processing Record 38 of Set 8 | lasa
# Processing Record 39 of Set 8 | cidreira
# Processing Record 40 of Set 8 | bristol
# Processing Record 41 of Set 8 | burica
# City not found. Skipping...
# Processing Record 42 of Set 8 | baruun-urt
# Processing Record 43 of Set 8 | beringovskiy
# Processing Record 44 of Set 8 | khani
# Processing Record 45 of Set 8 | belyy yar
# Processing Record 46 of Set 8 | high level
# Processing Record 47 of Set 8 | makakilo city
# Processing Record 48 of Set 8 | saint george
# Processing Record 49 of Set 8 | iskateley
# Processing Record 50 of Set 8 | matara
# Processing Record 1 of Set 9 | palembang
# Processing Record 2 of Set 9 | chowchilla
# Processing Record 3 of Set 9 | pagudpud
# Processing Record 4 of Set 9 | mackenzie
# Processing Record 5 of Set 9 | khovu-aksy
# Processing Record 6 of Set 9 | gweta
# Processing Record 7 of Set 9 | esso
# Processing Record 8 of Set 9 | viedma
# Processing Record 9 of Set 9 | kavieng
# Processing Record 10 of Set 9 | chipinge
# Processing Record 11 of Set 9 | sitka
# Processing Record 12 of Set 9 | nkhotakota
# Processing Record 13 of Set 9 | tromso
# Processing Record 14 of Set 9 | kenai
# Processing Record 15 of Set 9 | papar
# Processing Record 16 of Set 9 | krasnorechenskiy
# Processing Record 17 of Set 9 | caucaia
# Processing Record 18 of Set 9 | diu
# Processing Record 19 of Set 9 | moron
# Processing Record 20 of Set 9 | ondjiva
# Processing Record 21 of Set 9 | ripoll
# Processing Record 22 of Set 9 | meadow lake
# Processing Record 23 of Set 9 | vesoul
# Processing Record 24 of Set 9 | miraflores
# Processing Record 25 of Set 9 | yala
# Processing Record 26 of Set 9 | tuatapere
# Processing Record 27 of Set 9 | batagay
# Processing Record 28 of Set 9 | houma
# Processing Record 29 of Set 9 | thanh hoa
# Processing Record 30 of Set 9 | marquette
# Processing Record 31 of Set 9 | saint-philippe
# Processing Record 32 of Set 9 | mramor
# Processing Record 33 of Set 9 | bardiyah
# Processing Record 34 of Set 9 | capaci
# Processing Record 35 of Set 9 | port-gentil
# Processing Record 36 of Set 9 | kinshasa
# Processing Record 37 of Set 9 | camflora
# City not found. Skipping...
# Processing Record 38 of Set 9 | berlevag
# Processing Record 39 of Set 9 | santa rosa
# Processing Record 40 of Set 9 | ancud
# Processing Record 41 of Set 9 | grahamstown
# Processing Record 42 of Set 9 | valdemarpils
# Processing Record 43 of Set 9 | bambous virieux
# Processing Record 44 of Set 9 | tawnat
# City not found. Skipping...
# Processing Record 45 of Set 9 | skibbereen
# Processing Record 46 of Set 9 | muros
# Processing Record 47 of Set 9 | kirkwall
# Processing Record 48 of Set 9 | murmino
# Processing Record 49 of Set 9 | touros
# Processing Record 50 of Set 9 | mackay
# Processing Record 1 of Set 10 | kloulklubed
# Processing Record 2 of Set 10 | kysyl-syr
# Processing Record 3 of Set 10 | schoten
# Processing Record 4 of Set 10 | tiznit
# Processing Record 5 of Set 10 | okha
# Processing Record 6 of Set 10 | port lincoln
# Processing Record 7 of Set 10 | el vigia
# Processing Record 8 of Set 10 | badhni kalan
# Processing Record 9 of Set 10 | vanimo
# Processing Record 10 of Set 10 | portland
# Processing Record 11 of Set 10 | mareeba
# Processing Record 12 of Set 10 | kungurtug
# Processing Record 13 of Set 10 | lewisville
# Processing Record 14 of Set 10 | oranjestad
# Processing Record 15 of Set 10 | asau
# Processing Record 16 of Set 10 | turukhansk
# Processing Record 17 of Set 10 | mudgee
# Processing Record 18 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 10 | verkhnevilyuysk
# Processing Record 20 of Set 10 | zyryanka
# Processing Record 21 of Set 10 | sept-iles
# Processing Record 22 of Set 10 | veinticinco de mayo
# Processing Record 23 of Set 10 | dois vizinhos
# Processing Record 24 of Set 10 | lebanon
# Processing Record 25 of Set 10 | gainesville
# Processing Record 26 of Set 10 | sfantu gheorghe
# Processing Record 27 of Set 10 | vertientes
# Processing Record 28 of Set 10 | borogontsy
# Processing Record 29 of Set 10 | dangriga
# Processing Record 30 of Set 10 | buala
# Processing Record 31 of Set 10 | anadyr
# Processing Record 32 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 10 | solton
# Processing Record 34 of Set 10 | klaksvik
# Processing Record 35 of Set 10 | nizhnevartovsk
# Processing Record 36 of Set 10 | kruisfontein
# Processing Record 37 of Set 10 | colares
# Processing Record 38 of Set 10 | sampit
# Processing Record 39 of Set 10 | den helder
# Processing Record 40 of Set 10 | patrocinio
# Processing Record 41 of Set 10 | katangli
# Processing Record 42 of Set 10 | parati
# Processing Record 43 of Set 10 | ulaangom
# Processing Record 44 of Set 10 | christchurch
# Processing Record 45 of Set 10 | dikson
# Processing Record 46 of Set 10 | codcod
# Processing Record 47 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 48 of Set 10 | ilulissat
# Processing Record 49 of Set 10 | nanning
# Processing Record 50 of Set 10 | tilichiki
# Processing Record 1 of Set 11 | ybycui
# Processing Record 2 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 3 of Set 11 | swidwin
# Processing Record 4 of Set 11 | banbury
# Processing Record 5 of Set 11 | slupca
# Processing Record 6 of Set 11 | beidao
# Processing Record 7 of Set 11 | mazyr
# Processing Record 8 of Set 11 | nema
# Processing Record 9 of Set 11 | pangody
# Processing Record 10 of Set 11 | nacunday
# City not found. Skipping...
# Processing Record 11 of Set 11 | tutoia
# Processing Record 12 of Set 11 | kushmurun
# Processing Record 13 of Set 11 | sibolga
# Processing Record 14 of Set 11 | aizawl
# Processing Record 15 of Set 11 | boyolangu
# Processing Record 16 of Set 11 | panama city
# Processing Record 17 of Set 11 | port hardy
# Processing Record 18 of Set 11 | chicama
# Processing Record 19 of Set 11 | dholka
# Processing Record 20 of Set 11 | tabarqah
# City not found. Skipping...
# Processing Record 21 of Set 11 | aykino
# Processing Record 22 of Set 11 | kedrovyy
# Processing Record 23 of Set 11 | vardo
# Processing Record 24 of Set 11 | kindu
# Processing Record 25 of Set 11 | whitehorse
# Processing Record 26 of Set 11 | auki
# Processing Record 27 of Set 11 | biswan
# Processing Record 28 of Set 11 | livingston
# Processing Record 29 of Set 11 | portoferraio
# Processing Record 30 of Set 11 | malibu
# Processing Record 31 of Set 11 | kholmogory
# Processing Record 32 of Set 11 | bilma
# Processing Record 33 of Set 11 | opuwo
# Processing Record 34 of Set 11 | gisborne
# Processing Record 35 of Set 11 | namibe
# Processing Record 36 of Set 11 | honningsvag
# Processing Record 37 of Set 11 | iquitos
# Processing Record 38 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 39 of Set 11 | odweyne
# Processing Record 40 of Set 11 | ornskoldsvik
# Processing Record 41 of Set 11 | mehamn
# Processing Record 42 of Set 11 | rio bueno
# Processing Record 43 of Set 11 | ternate
# Processing Record 44 of Set 11 | urfa
# City not found. Skipping...
# Processing Record 45 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 46 of Set 11 | luanda
# Processing Record 47 of Set 11 | prince rupert
# Processing Record 48 of Set 11 | mayo
# Processing Record 49 of Set 11 | aasiaat
# Processing Record 50 of Set 11 | kenora
# Processing Record 1 of Set 12 | xining
# Processing Record 2 of Set 12 | lithgow
# Processing Record 3 of Set 12 | gat
# Processing Record 4 of Set 12 | kalmunai
# Processing Record 5 of Set 12 | farau
# Processing Record 6 of Set 12 | chaoyang
# Processing Record 7 of Set 12 | darhan
# Processing Record 8 of Set 12 | praia
# Processing Record 9 of Set 12 | waingapu
# Processing Record 10 of Set 12 | tazovskiy
# Processing Record 11 of Set 12 | taguisa
# Processing Record 12 of Set 12 | maniitsoq
# Processing Record 13 of Set 12 | jurm
# Processing Record 14 of Set 12 | bandar-e lengeh
# Processing Record 15 of Set 12 | jacareacanga
# Processing Record 16 of Set 12 | kahului
# Processing Record 17 of Set 12 | acapulco
# Processing Record 18 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 12 | pisco
# Processing Record 20 of Set 12 | caranavi
# Processing Record 21 of Set 12 | clyde river
# Processing Record 22 of Set 12 | lephepe
# City not found. Skipping...
# Processing Record 23 of Set 12 | ust-tsilma
# Processing Record 24 of Set 12 | camana
# Processing Record 25 of Set 12 | nelson bay
# Processing Record 26 of Set 12 | ewa beach
# Processing Record 27 of Set 12 | hendijan
# City not found. Skipping...
# Processing Record 28 of Set 12 | grand-lahou
# Processing Record 29 of Set 12 | pirenopolis
# Processing Record 30 of Set 12 | oudtshoorn
# Processing Record 31 of Set 12 | merritt island
# Processing Record 32 of Set 12 | ust-ilimsk
# Processing Record 33 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 12 | gondanglegi
# Processing Record 35 of Set 12 | vilhena
# Processing Record 36 of Set 12 | dmitriyev-lgovskiy
# City not found. Skipping...
# Processing Record 37 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 12 | mataram
# Processing Record 39 of Set 12 | hasaki
# Processing Record 40 of Set 12 | ayan
# Processing Record 41 of Set 12 | faya
# Processing Record 42 of Set 12 | north bend
# Processing Record 43 of Set 12 | nagai
# Processing Record 44 of Set 12 | zeerust
# Processing Record 45 of Set 12 | byron bay
# Processing Record 46 of Set 12 | xai-xai
# Processing Record 47 of Set 12 | pacifica
# Processing Record 48 of Set 12 | wanning
# Processing Record 49 of Set 12 | kingsville
# Processing Record 50 of Set 12 | pokaran
# Processing Record 1 of Set 13 | cavalcante
# Processing Record 2 of Set 13 | samarkand
# Processing Record 3 of Set 13 | kathmandu
# Processing Record 4 of Set 13 | samarai
# Processing Record 5 of Set 13 | zhanakorgan
# Processing Record 6 of Set 13 | turayf
# Processing Record 7 of Set 13 | nalut
# Processing Record 8 of Set 13 | tambul
# City not found. Skipping...
# Processing Record 9 of Set 13 | krasnyy chikoy
# Processing Record 10 of Set 13 | tadine
# Processing Record 11 of Set 13 | vagur
# Processing Record 12 of Set 13 | blackwater
# Processing Record 13 of Set 13 | san miguel
# Processing Record 14 of Set 13 | karratha
# Processing Record 15 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 16 of Set 13 | tchibanga
# Processing Record 17 of Set 13 | barabai
# Processing Record 18 of Set 13 | novoagansk
# Processing Record 19 of Set 13 | nicoya
# Processing Record 20 of Set 13 | shiyan
# Processing Record 21 of Set 13 | amurzet
# Processing Record 22 of Set 13 | karasuyama
# Processing Record 23 of Set 13 | santa fe
# Processing Record 24 of Set 13 | mastic beach
# Processing Record 25 of Set 13 | vidalia
# Processing Record 26 of Set 13 | basco
# Processing Record 27 of Set 13 | antibes
# Processing Record 28 of Set 13 | songjianghe
# Processing Record 29 of Set 13 | digoin
# Processing Record 30 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 31 of Set 13 | dukat
# Processing Record 32 of Set 13 | isiro
# Processing Record 33 of Set 13 | naze
# Processing Record 34 of Set 13 | ostrovnoy
# Processing Record 35 of Set 13 | senador jose porfirio
# Processing Record 36 of Set 13 | hambantota
# Processing Record 37 of Set 13 | tabligbo
# Processing Record 38 of Set 13 | khilok
# Processing Record 39 of Set 13 | capim grosso
# Processing Record 40 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 41 of Set 13 | paamiut
# Processing Record 42 of Set 13 | san andres
# Processing Record 43 of Set 13 | margate
# Processing Record 44 of Set 13 | zafra
# Processing Record 45 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 46 of Set 13 | port augusta
# Processing Record 47 of Set 13 | dabakala
# Processing Record 48 of Set 13 | leningradskiy
# Processing Record 49 of Set 13 | zhangjiakou
# Processing Record 50 of Set 13 | akonolinga
# Processing Record 1 of Set 14 | pelotas
# Processing Record 2 of Set 14 | joshimath
# Processing Record 3 of Set 14 | chumphon
# Processing Record 4 of Set 14 | palauig
# Processing Record 5 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 6 of Set 14 | tingrela
# City not found. Skipping...
# Processing Record 7 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 14 | saint-pierre
# Processing Record 9 of Set 14 | sisophon
# Processing Record 10 of Set 14 | nemuro
# Processing Record 11 of Set 14 | quatre cocos
# Processing Record 12 of Set 14 | oranjemund
# Processing Record 13 of Set 14 | san lawrenz
# Processing Record 14 of Set 14 | chapada dos guimaraes
# Processing Record 15 of Set 14 | elizabeth city
# Processing Record 16 of Set 14 | itoman
# Processing Record 17 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 18 of Set 14 | kakonko
# Processing Record 19 of Set 14 | usinsk
# Processing Record 20 of Set 14 | ferkessedougou
# Processing Record 21 of Set 14 | sabinas hidalgo
# Processing Record 22 of Set 14 | nizhniy kuranakh
# Processing Record 23 of Set 14 | hearst
# Processing Record 24 of Set 14 | san pedro de macoris
# Processing Record 25 of Set 14 | nowe miasto lubawskie
# Processing Record 26 of Set 14 | jacksonville
# Processing Record 27 of Set 14 | northam
# Processing Record 28 of Set 14 | pec
# Processing Record 29 of Set 14 | lamu
# Processing Record 30 of Set 14 | umm kaddadah
# Processing Record 31 of Set 14 | port moresby
# Processing Record 32 of Set 14 | galich
# Processing Record 33 of Set 14 | vryburg
# Processing Record 34 of Set 14 | hirara
# Processing Record 35 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 14 | madang
# Processing Record 37 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 38 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 14 | naryan-mar
# Processing Record 40 of Set 14 | parrita
# Processing Record 41 of Set 14 | barcelona
# Processing Record 42 of Set 14 | sangar
# Processing Record 43 of Set 14 | tra vinh
# Processing Record 44 of Set 14 | vaitape
# Processing Record 45 of Set 14 | westport
# Processing Record 46 of Set 14 | launceston
# Processing Record 47 of Set 14 | tura
# Processing Record 48 of Set 14 | lerwick
# Processing Record 49 of Set 14 | rodrigues alves
# Processing Record 50 of Set 14 | tomatlan
# Processing Record 1 of Set 15 | grindavik
# Processing Record 2 of Set 15 | raga
# Processing Record 3 of Set 15 | kudahuvadhoo
# Processing Record 4 of Set 15 | benin
# Processing Record 5 of Set 15 | the pas
# Processing Record 6 of Set 15 | bentiu
# Processing Record 7 of Set 15 | shangrao
# Processing Record 8 of Set 15 | yialos
# City not found. Skipping...
# Processing Record 9 of Set 15 | almeirim
# Processing Record 10 of Set 15 | mutata
# Processing Record 11 of Set 15 | yablonovo
# Processing Record 12 of Set 15 | adrar
# Processing Record 13 of Set 15 | hobyo
# Processing Record 14 of Set 15 | viisoara
# Processing Record 15 of Set 15 | kangaatsiaq
# Processing Record 16 of Set 15 | tommot
# Processing Record 17 of Set 15 | roblin
# Processing Record 18 of Set 15 | pondicherry
# Processing Record 19 of Set 15 | alugan
# Processing Record 20 of Set 15 | charters towers
# Processing Record 21 of Set 15 | bonthe
# Processing Record 22 of Set 15 | lebedyn
# Processing Record 23 of Set 15 | inhambane
# Processing Record 24 of Set 15 | te anau
# Processing Record 25 of Set 15 | coahuayana
# Processing Record 26 of Set 15 | nouadhibou
# Processing Record 27 of Set 15 | savelugu
# Processing Record 28 of Set 15 | meulaboh
# Processing Record 29 of Set 15 | verkhoyansk
# Processing Record 30 of Set 15 | presidente epitacio
# Processing Record 31 of Set 15 | barsovo
# Processing Record 32 of Set 15 | ofaqim
# Processing Record 33 of Set 15 | swan hill
# Processing Record 34 of Set 15 | broken hill
# Processing Record 35 of Set 15 | turka
# Processing Record 36 of Set 15 | jimenez
# Processing Record 37 of Set 15 | marienburg
# Processing Record 38 of Set 15 | lazaro cardenas
# Processing Record 39 of Set 15 | polunochnoye
# Processing Record 40 of Set 15 | pleasanton
# Processing Record 41 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 15 | laguna
# Processing Record 43 of Set 15 | sioux lookout
# Processing Record 44 of Set 15 | manjacaze
# Processing Record 45 of Set 15 | chokwe
# Processing Record 46 of Set 15 | chiredzi
# Processing Record 47 of Set 15 | kristiinankaupunki
# Processing Record 48 of Set 15 | safaga
# Processing Record 49 of Set 15 | verkhnyaya inta
# Processing Record 50 of Set 15 | cap malheureux
# Processing Record 1 of Set 16 | rayong
# Processing Record 2 of Set 16 | wright
# Processing Record 3 of Set 16 | paracuru
# Processing Record 4 of Set 16 | melilla
# Processing Record 5 of Set 16 | chak jhumra
# Processing Record 6 of Set 16 | carlyle
# Processing Record 7 of Set 16 | saint-maximin-la-sainte-baume
# Processing Record 8 of Set 16 | ilo
# Processing Record 9 of Set 16 | susangerd
# Processing Record 10 of Set 16 | cockburn town
# Processing Record 11 of Set 16 | moldava nad bodvou
# Processing Record 12 of Set 16 | udachnyy
# Processing Record 13 of Set 16 | diego de almagro
# Processing Record 14 of Set 16 | hondo
# Processing Record 15 of Set 16 | langsa
# Processing Record 16 of Set 16 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 17 of Set 16 | ksenyevka
# City not found. Skipping...
# Processing Record 18 of Set 16 | ambilobe
# Processing Record 19 of Set 16 | strezhevoy
# Processing Record 20 of Set 16 | acarau
# Processing Record 21 of Set 16 | esmeraldas
# Processing Record 22 of Set 16 | havoysund
# Processing Record 23 of Set 16 | solnechnyy
# Processing Record 24 of Set 16 | bilibino
# Processing Record 25 of Set 16 | santa vitoria
# Processing Record 26 of Set 16 | muana
# Processing Record 27 of Set 16 | lompoc
# Processing Record 28 of Set 16 | jinchang
# Processing Record 29 of Set 16 | komsomolets
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Castro -24.7911  -50.0119     65.25        71          11        4.74
# 1      Sidney -33.8679  151.2073     55.40        47          20       17.27
# 2    Khatanga  71.9667  102.5000     16.11        84          98       11.25
# 3       Bluff -46.6000  168.3333     55.99        97          31        8.01
# 4      Avarua -21.2078 -159.7750     82.40        78          35        6.91
# 5      Narsaq  60.9167  -46.0500     48.20        29           0       13.80
# 6      Monywa  22.1167   95.1333     86.18        34           8        5.35
# 7        Hilo  19.7297 -155.0900     80.60        44           1       11.50
# 8     Rikitea -23.1203 -134.9692     78.30        74           7        8.19
# 9  Bredasdorp -34.5322   20.0403     57.20        94         100        1.14
#
#   Country                 Date Current Description
# 0      BR  2021-04-11 22:21:59          few clouds
# 1      AU  2021-04-11 22:17:29          few clouds
# 2      RU  2021-04-11 22:22:00     overcast clouds
# 3      NZ  2021-04-11 22:22:00    scattered clouds
# 4      CK  2021-04-11 22:22:00       moderate rain
# 5      GL  2021-04-11 22:22:01           clear sky
# 6      MM  2021-04-11 22:22:01           clear sky
# 7      US  2021-04-11 22:18:44           clear sky
# 8      PF  2021-04-11 22:21:56          light rain
# 9      ZA  2021-04-11 22:22:01     overcast clouds

# %%
# Reorder the column order
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", 
                    "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Castro      BR -24.7911  -50.0119     65.25        71          11
# 1      Sidney      AU -33.8679  151.2073     55.40        47          20
# 2    Khatanga      RU  71.9667  102.5000     16.11        84          98
# 3       Bluff      NZ -46.6000  168.3333     55.99        97          31
# 4      Avarua      CK -21.2078 -159.7750     82.40        78          35
# 5      Narsaq      GL  60.9167  -46.0500     48.20        29           0
# 6      Monywa      MM  22.1167   95.1333     86.18        34           8
# 7        Hilo      US  19.7297 -155.0900     80.60        44           1
# 8     Rikitea      PF -23.1203 -134.9692     78.30        74           7
# 9  Bredasdorp      ZA -34.5322   20.0403     57.20        94         100
#
#    Wind Speed Current Description
# 0        4.74          few clouds
# 1       17.27          few clouds
# 2       11.25     overcast clouds
# 3        8.01    scattered clouds
# 4        6.91       moderate rain
# 5       13.80           clear sky
# 6        5.35           clear sky
# 7       11.50           clear sky
# 8        8.19          light rain
# 9        1.14     overcast clouds

# %%
# Exporting File
file_to_save = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(file_to_save, index_label="City_ID")
